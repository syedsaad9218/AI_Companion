# %%
import pandas as pd

# %%
df = pd.read_csv('activitywatch_log.csv')
df.head(20)
# Out:
#           duration       app  \
# 0   0:00:01.149000  Code.exe
# 1   0:00:01.028000  Code.exe
# 2   0:00:04.251000  Code.exe
# 3          0:00:00  Code.exe
# 4   0:00:06.160000  Code.exe
# 5   0:00:04.364000  Code.exe
# 6   0:00:12.477000  Code.exe
# 7          0:00:00  Code.exe
# 8   0:00:20.563000  Code.exe
# 9   0:00:18.701000  Code.exe
# 10  0:00:19.663000  Code.exe
# 11  0:00:01.036000  Code.exe
# 12  0:00:14.484000  Code.exe
# 13  0:00:07.399000  Code.exe
# 14  0:00:12.629000  Code.exe
# 15  0:00:05.131000  Code.exe
# 16  0:00:05.253000  Code.exe
# 17  0:00:04.305000  Code.exe
# 18         0:00:00  Code.exe
# 19  0:00:22.959000  Code.exe
#
#                                                 title  url
# 0                                  Visual Studio Code  NaN
# 1   activitywatch_log.csv - Ai_companion - Visual ...  NaN
# 2         test.py - Ai_companion - Visual Studio Code  NaN
# 3       ● test.py - Ai_companion - Visual Studio Code  NaN
# ...
